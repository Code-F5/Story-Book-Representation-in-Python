# %% [markdown]
# Sumit Patil

# %%
conda install <the library>
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The syntax of the command is incorrect.

# %%
from IPython.display import Image
Image(filename='python-cartoons-hw/Sumit/the lion and mouse/60.jpg', width=50)
##display the image

# %%
from PIL import Image as pili, ImageOps as piliops

piliops.expand(pili.open('python-cartoons-hw/Sumit/the lion and mouse/60.jpg'), border=(100,100),fill='white').save('python-cartoons-hw/Sumit/the lion and mouse/60_1.jpeg')
##add border to the

# %%
Image(filename='python-cartoons-hw/Sumit/the lion and mouse/60_1.jpeg', width=400)

# %%
from PIL import Image as pili, ImageDraw as pild, ImageFont as pilf 

caption = """Was I not right?” said the little Mouse."""

TINT_COLOR = (0, 0, 0)  # Black
TRANSPARENCY = .25  # Degree of transparency, 0-100%
OPACITY = int(255 * TRANSPARENCY)

from PIL import Image, ImageFont, ImageDraw

img = pili.open('python-cartoons-hw/Sumit/the lion and mouse/60_1.jpeg').convert('RGBA')

overlay = pili.new('RGBA', img.size, TINT_COLOR+(0,))
draw = pild.Draw(overlay)
font = ImageFont.load_default() 
x, y = (img.width - 510, img.height-100)
text = caption
w, h = font.getsize(text)
num_lines = len(text.split('\n'))
print(num_lines, w, h)
x, y = 100, img.height - (num_lines-0.1*num_lines)*h
draw.rectangle((x, y, x + w, y + h), fill='black')
draw.rectangle((x, y, x + w, y + 4*h), fill=TINT_COLOR+(OPACITY,))
draw.rectangle((x, y, x + img.width - 200, y + (num_lines-0.1*num_lines)*h), fill=TINT_COLOR+(OPACITY,))
draw.text((x, y), text, fill=(0, 0, 0), font=font)

# Alpha composite these two images together to obtain the desired result.
img = pili.alpha_composite(img, overlay)
img = img.convert("RGB") # Remove alpha for saving in jpg format.

img.save('python-cartoons-hw/Sumit/the lion and mouse/60.jpeg')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7184/1552655336.py in <module>
#      16 x, y = (img.width - 510, img.height-100)
#      17 text = caption
# ---> 18 w, h = font.getsize(text)
#      19 num_lines = len(text.split('\n'))
#      20 print(num_lines, w, h)
#
# ~\anaconda3\envs\Renv\lib\site-packages\PIL\ImageFont.py in getsize(self, text, *args, **kwargs)
#     127         :return: (width, height)
#     128         """
# --> 129         return self.font.getsize(text)
#     130
#     131     def getmask(self, text, mode="", *args, **kwargs):
#
# UnicodeEncodeError: 'latin-1' codec can't encode character '\u201d' in position 16: ordinal not in range(256)

# %%
from IPython.display import Image
Image(filename='python-cartoons-hw/Sumit/the lion and mouse/60_1.jpeg', width=200)

# %%
import pandas as pd
data = pd.read_csv('python-cartoons-hw/the lion and mouse dialog.csv')
data.head(10)
# Out:
#                     dialog
# 0  Once there was a mouse.
# 1  Once there was a mouse.

# %%
import numpy as np
data.values[0][0]
# Out:
# 'Once there was a mouse.'

# %%
from PIL import Image as pili, ImageOps as piliops

piliops.expand(pili.open('python-cartoons-hw/Sumit/the lion and mouse/2.jpg'), border=(100,100),fill='white').save('python-cartoons-hw/Sumit/the lion and mouse/2_1.jpeg')
##add border to the image

# %%
from PIL import Image as pili, ImageDraw as pild, ImageFont as pilf 

caption = """Who used to scare alot of other animals."""

TINT_COLOR = (0, 0, 0)  # Black
TRANSPARENCY = .25  # Degree of transparency, 0-100%
OPACITY = int(255 * TRANSPARENCY)

from PIL import Image, ImageFont, ImageDraw

img = pili.open('python-cartoons-hw/Sumit/the lion and mouse/1_1.jpg').convert('RGBA')

overlay = pili.new('RGBA', img.size, TINT_COLOR+(0,))
draw = pild.Draw(overlay)
font = ImageFont.load_default()
#x, y = (img.width - 510, img.height-100)
text = caption
w, h = font.getsize(text)
num_lines = len(text.split('\n'))
print(num_lines, w, h)
x, y = 100, img.height - (num_lines-0.1*num_lines)*h
#draw.rectangle((x, y, x + w, y + h), fill='black')
#draw.rectangle((x, y, x + w, y + 4*h), fill=TINT_COLOR+(OPACITY,))
draw.rectangle((x, y, x + img.width - 200, y + (num_lines-0.1*num_lines)*h), fill=TINT_COLOR+(OPACITY,))
draw.text((x, y), text, fill=(0, 0, 0), font=font)

# Alpha composite these two images together to obtain the desired result.
img = pili.alpha_composite(img, overlay)
img = img.convert("RGB") # Remove alpha for saving in jpg format.

img.save('python-cartoons-hw/Sumit/the lion and mouse/1.jpg')
# Out:
# 1 240 11

# %%
from PIL import Image as pili, ImageOps as piliops

piliops.expand(pili.open('python-cartoons-hw/Sumit/the lion and mouse/4.jpeg'), border=(100,100),fill='white').save('python-cartoons-hw/Sumit/the lion and mouse/4_1.jpeg')
##add border to the image
from PIL import Image as pili, ImageDraw as pild, ImageFont as pilf 

caption = """Every animals used to make fun of him.
"""

TINT_COLOR = (0, 0, 0)  # Black
TRANSPARENCY = .25  # Degree of transparency, 0-100%
OPACITY = int(255 * TRANSPARENCY)

from PIL import Image, ImageFont, ImageDraw

img = pili.open('python-cartoons-hw/Sumit/the lion and mouse/4_1.jpeg').convert('RGBA')

overlay = pili.new('RGBA', img.size, TINT_COLOR+(0,))
draw = pild.Draw(overlay)
font = ImageFont.load_default()
#x, y = (img.width - 510, img.height-100)
text = caption
w, h = font.getsize(text)
num_lines = len(text.split('\n'))
print(num_lines, w, h)
x, y = 100, img.height - (num_lines-0.1*num_lines)*h
#draw.rectangle((x, y, x + w, y + h), fill='black')
#draw.rectangle((x, y, x + w, y + 4*h), fill=TINT_COLOR+(OPACITY,))
draw.rectangle((x, y, x + img.width - 200, y + (num_lines-0.1*num_lines)*h), fill=TINT_COLOR+(OPACITY,))
draw.text((x, y), text, fill=(0, 0, 0), font=font)

# Alpha composite these two images together to obtain the desired result.
img = pili.alpha_composite(img, overlay)
img = img.convert("RGB") # Remove alpha for saving in jpg format.

img.save('python-cartoons-hw/Sumit/the lion and mouse/4.jpg')

##So this cell it is basically a cell for producing English Subtitles
##Therefore instead of repeating the code again and again which is all same except for the image address
##I will adjust the address to get the images with subtitles by changing the code in this cell
# Out:
# 2 228 11

# %%
import numpy as np
import PIL

list_im = ['python-cartoons-hw/Sumit/the lion and mouse/57.jpeg',
            'python-cartoons-hw/Sumit/the lion and mouse/58.jpeg',
            'python-cartoons-hw/Sumit/the lion and mouse/59.jpeg',
            'python-cartoons-hw/Sumit/the lion and mouse/60.jpg']
imgs    = [ PIL.Image.open(i) for i in list_im ]

# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
imgs_comb.save( 'python-cartoons-hw/Sumit/the lion and mouse/15.jpg' )  
##so i will stick horizontal ones together
##and i will not repeat the same code over and over again
#i will just use this cell to do the horizontal stitich
# Out:
# C:\Users\Dell\anaconda3\envs\Renv\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if sys.path[0] == '':

# %%
pip install fpdf
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The filename, directory name, or volume label syntax is incorrect.

# %%
from PIL import Image
from fpdf import FPDF

#pdf = FPDF()
cover = Image.open('python-cartoons-hw/Sumit/the lion and mouse/cover.jpg')
width, height = cover.size
pdf = FPDF(unit = "pt", format = [width,height])
    
# imagelist is the list with all image filenames
imagelist = ['python-cartoons-hw/Sumit/the lion and mouse/1.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/2.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/3.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/4.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/5.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/6.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/7.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/8.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/9.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/10.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/11.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/12.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/13.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/14.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/15.jpg',]

for image in imagelist:
    pdf.add_page()
    pdf.image(image, 0, 200, 1300, 0)
pdf.output("python-cartoons-hw/Sumit/the lion and mouse/the lion and mouse.pdf", "F")
print("done!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7184/309198557.py in <module>
#       1 from PIL import Image
# ----> 2 from fpdf import FPDF
#       3
#       4 #pdf = FPDF()
#       5 cover = Image.open('python-cartoons-hw/Sumit/the lion and mouse/cover.jpg')
#
# ModuleNotFoundError: No module named 'fpdf'

# %%
import numpy as np
import PIL

list_im = ['python-cartoons-hw/Sumit/the lion and mouse/57.jpg',
            'python-cartoons-hw/Sumit/the lion and mouse/58.jpg',
            'python-cartoons-hw/Sumit/the lion and mouse/59.jpg',
            'python-cartoons-hw/Sumit/the lion and mouse/60.jpg']
imgs    = [ PIL.Image.open(i) for i in list_im ]

# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
imgs_comb.save( 'python-cartoons-hw/Sumit/the lion and mouse/15.jpg' )  
##so i will stick horizontal ones together
##and i will not repeat the same code over and over again
#i will just use this cell to do the horizontal stitich
# Out:
# C:\Users\Dell\anaconda3\envs\Renv\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if sys.path[0] == '':

# %%
from PIL import Image
from fpdf import FPDF

#pdf = FPDF()
cover = Image.open('python-cartoons-hw/Sumit/the lion and mouse/cover.jp g')
width, height = cover.size
pdf = FPDF(unit = "pt", format = [width,height])
    
# imagelist is the list with all image filenames
imagelist = ['python-cartoons-hw/Sumit/the lion and mouse/1.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/2.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/3.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/4.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/5.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/6.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/7.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/8.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/9.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/10.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/11.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/12.jpg',
             'python-cartoons-hw/Sumit/the lion and mouse/13.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/14.jpg', 
             'python-cartoons-hw/Sumit/the lion and mouse/15.jpg',]

for image in imagelist:
    pdf.add_page()
    pdf.image(image, 0, 200, 1300, 0)
pdf.output("python-cartoons-hw/Sumit/the lion and mouse/the lion and mouse.pdf", "F")
print("done!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7184/309198557.py in <module>
#       1 from PIL import Image
# ----> 2 from fpdf import FPDF
#       3
#       4 #pdf = FPDF()
#       5 cover = Image.open('python-cartoons-hw/Sumit/the lion and mouse/cover.jpg')
#
# ModuleNotFoundError: No module named 'fpdf'
